# %%
import  PIL
from PIL import Image
import numpy

# %%
img = Image.open("image2.jpg").convert('RGB')
img
# Out:
# <PIL.Image.Image image mode=RGB size=1200x675 at 0x20461D87208>

# %%
r, g, b = img.split()

# %%
img_r = img_rgb[[[0]]]
img_r
# Out:
# array([[[134,  77,   0],
#         [129,  79,  10],
#         [115,  74,  20],
#         ...,
#         [ 15,  11,  10],
#         [ 15,   9,   9],
#         [ 14,   8,  10]]], dtype=uint8)
