# %%
import  PIL
from PIL import Image
import numpy

# %%
img = Image.open("image2.jpg").convert('RGB')
img
# Out:
# <PIL.Image.Image image mode=RGB size=1200x675 at 0x2C3A39D86A0>

# %%
r, g, b = img.split()
r
# Out:
# <PIL.Image.Image image mode=L size=1200x675 at 0x2C3A3DFA550>

# %%
g
# Out:
# <PIL.Image.Image image mode=L size=1200x675 at 0x2C3A3DFA630>

# %%
b
# Out:
# <PIL.Image.Image image mode=L size=1200x675 at 0x2C3A3DFA6A0>
